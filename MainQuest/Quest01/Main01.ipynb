# %%
#주요 변경사항:
 #인코더 제거 - 디코더만 사용하는 GPT-1 구조
 #masked Self-Attention 추가 - 미래 토큰 참조 방지
 #학습 가능한 Position Embedding (sinusoidal → learned)
 #GELU 활성화 함수 적용 (ReLU → GELU)
 #Pre-LayerNorm 구조 적용
 #단일 시퀀스 처리 방식으로 변경
 #언어 모델링 목적함수로 변경

# %%
# !pip install sentencepiece scikit-learn

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import sentencepiece as spm
import math
import os
import re
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.12/site-packages (0.2.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (3.6.0)

# %%
# ===== 1. 경로 설정 =====
base_dir = os.path.expanduser("~/work/transformer_chatbot/data")
os.makedirs(base_dir, exist_ok=True)
csv_path = os.path.join(base_dir, "ChatbotData.csv")
train_txt = os.path.join(base_dir, "ChatbotData_clean.txt")
model_pref = os.path.join(base_dir, "spm_chatbot")

# %%
# ===== 2. 데이터 전처리 =====
df = pd.read_csv(csv_path)
print("원본 데이터 크기:", df.shape)

df = df.dropna(subset=['Q', 'A'])
df = df.drop_duplicates(subset=['Q', 'A'])

def clean_text(text):
    text = str(text)
    text = re.sub(r"[^가-힣0-9ㄱ-ㅎㅏ-ㅣ .,!?~]+", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    text = re.sub(r"(ㅋ){2,}", "ㅋㅋ", text)
    text = re.sub(r"(ㅎ){2,}", "ㅎㅎ", text)
    return text

df['Q'] = df['Q'].apply(clean_text)
df['A'] = df['A'].apply(clean_text)
print("전처리 후 데이터 크기:", df.shape)

# txt 파일 저장 - GPT-1 방식으로 변경: Q + A를 하나의 시퀀스로 연결
with open(train_txt, "w", encoding="utf-8") as f:
    for q, a in zip(df['Q'], df['A']):
        # 변경사항: Q와 A를 하나의 시퀀스로 연결 (GPT-1 방식)
        combined = q + " <SEP> " + a
        f.write(combined + "\n")
# Out:
# 원본 데이터 크기: (11823, 3)
# 전처리 후 데이터 크기: (11750, 3)

# %%
# ===== 3. SentencePiece 학습 (특수 토큰 수정) =====
# 변경사항: GPT-1에 맞는 특수 토큰 추가
spm.SentencePieceTrainer.Train(
    f"--input={train_txt} "
    f"--model_prefix={model_pref} "
    f"--vocab_size=8000 "
    f"--character_coverage=0.9995 "
    f"--model_type=bpe "
    f"--user_defined_symbols=<BOS>,<EOS>,<PAD>,<SEP> "  # <SEP> 토큰 추가
    f"--pad_id=0 --bos_id=1 --eos_id=2 --unk_id=3"
)

# 토크나이저 로드
sp = spm.SentencePieceProcessor()
sp.load(f"{model_pref}.model")

# 특수 토큰 ID
PAD_ID = sp.piece_to_id('<PAD>')
BOS_ID = sp.piece_to_id('<BOS>')
EOS_ID = sp.piece_to_id('<EOS>')
UNK_ID = sp.piece_to_id('<UNK>')
SEP_ID = sp.piece_to_id('<SEP>')  # 추가: 구분자 토큰
vocab_size = sp.get_piece_size()

print(f"PAD_ID: {PAD_ID}, BOS_ID: {BOS_ID}, EOS_ID: {EOS_ID}, SEP_ID: {SEP_ID}, vocab_size: {vocab_size}")
# Out:
# PAD_ID: 6, BOS_ID: 4, EOS_ID: 5, SEP_ID: 7, vocab_size: 8000
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=/home/jovyan/work/transformer_chatbot/data/ChatbotData_clean.txt --model_prefix=/home/jovyan/work/transformer_chatbot/data/spm_chatbot --vocab_size=8000 --character_coverage=0.9995 --model_type=bpe --user_defined_symbols=<BOS>,<EOS>,<PAD>,<SEP> --pad_id=0 --bos_id=1 --eos_id=2 --unk_id=3
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /home/jovyan/work/transformer_chatbot/data/ChatbotData_clean.txt
#   input_format:
#   model_prefix: /home/jovyan/work/transformer_chatbot/data/spm_chatbot
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <BOS>
#   user_defined_symbols: <EOS>
#   user_defined_symbols: <PAD>
#   user_defined_symbols: <SEP>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: /home/jovyan/work/transformer_chatbot/data/ChatbotData_clean.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 11750 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <BOS>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <EOS>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <PAD>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <SEP>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=374746
# trainer_interface.cc(552) LOG(INFO) Done: 99.9504% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1059
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999504
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 11750 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 11750
# trainer_interface.cc(611) LOG(INFO) Done! 21758
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3320 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1029 size=20 all=16170 active=1814 piece=▁생
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=756 size=40 all=16882 active=2526 piece=▁너
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=568 size=60 all=17519 active=3163 piece=해보세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=420 size=80 all=18186 active=3830 piece=나봐요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=351 size=100 all=18911 active=4555 piece=▁좀
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=349 min_freq=37
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=296 size=120 all=19409 active=1499 piece=▁제
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=261 size=140 all=19938 active=2028 piece=▁진
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=225 size=160 all=20338 active=2428 piece=친구가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=201 size=180 all=20668 active=2758 piece=▁짝남
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=186 size=200 all=21042 active=3132 piece=사랑
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=184 min_freq=31
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=168 size=220 all=21406 active=1390 piece=▁혼자
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=240 all=21723 active=1707 piece=▁고민
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=260 all=22095 active=2079 piece=지만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=280 all=22456 active=2440 piece=▁짝녀
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=300 all=22743 active=2727 piece=▁충
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=127 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=320 all=23115 active=1503 piece=▁불
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=340 all=23481 active=1869 piece=▁아닌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=108 size=360 all=23712 active=2100 piece=랍니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=102 size=380 all=24030 active=2418 piece=▁쓰
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=400 all=24422 active=2810 piece=▁분
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=97 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=420 all=24659 active=1438 piece=▁맘
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=440 all=24926 active=1705 piece=하죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=460 all=25156 active=1935 piece=부터
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=480 all=25431 active=2210 piece=▁누구
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=500 all=25671 active=2450 piece=▁운동
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=77 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=520 all=25887 active=1483 piece=▁있는데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=540 all=26122 active=1718 piece=▁노력
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=560 all=26391 active=1987 piece=▁인연
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=580 all=26566 active=2162 piece=▁싶은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=600 all=26733 active=2329 piece=가요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=63 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=620 all=26921 active=1502 piece=▁노래
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=640 all=27172 active=1753 piece=▁어때
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=660 all=27445 active=2026 piece=▁천
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=680 all=27609 active=2190 piece=▁생각해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=700 all=27731 active=2312 piece=▁도움이
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=720 all=27899 active=1555 piece=▁언젠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=740 all=28054 active=1710 piece=▁말아요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=760 all=28158 active=1814 piece=▁오늘도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=780 all=28357 active=2013 piece=▁솔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=800 all=28474 active=2130 piece=▁프
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=46 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=820 all=28577 active=1522 piece=▁진심
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=840 all=28710 active=1655 piece=▁알려
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=860 all=28825 active=1770 piece=▁중요해요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=880 all=28917 active=1862 piece=적이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=900 all=29077 active=2022 piece=▁짧
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=40 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=920 all=29175 active=1540 piece=▁마시
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=940 all=29406 active=1771 piece=▁눈물
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=960 all=29505 active=1870 piece=▁똑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=980 all=29646 active=2011 piece=▁봄
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=1000 all=29817 active=2182 piece=▁괜찮은
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=1020 all=29932 active=1603 piece=▁보여
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=1040 all=30117 active=1788 piece=▁살펴
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=1060 all=30244 active=1915 piece=이별
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=1080 all=30376 active=2047 piece=▁응
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=1100 all=30462 active=2133 piece=▁서로에게
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=32 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1120 all=30528 active=1590 piece=▁즐거
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1140 all=30660 active=1722 piece=▁이겨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1160 all=30755 active=1817 piece=▁거짓
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1180 all=30855 active=1917 piece=▁좋아해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=1200 all=30932 active=1994 piece=▁응원
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=28 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=1220 all=31015 active=1624 piece=사를
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=1240 all=31113 active=1722 piece=▁싶네요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=1260 all=31191 active=1800 piece=움을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=1280 all=31229 active=1838 piece=▁진정
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=1300 all=31297 active=1906 piece=▁필요해요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=26 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=1320 all=31456 active=1724 piece=▁생길
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=1340 all=31515 active=1783 piece=▁언제나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=1360 all=31566 active=1834 piece=▁꾸준
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=1380 all=31668 active=1936 piece=▁가세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=1400 all=31675 active=1943 piece=▁채
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=23 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=1420 all=31818 active=1723 piece=▁어울
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=1440 all=31920 active=1825 piece=▁이제는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=1460 all=31974 active=1879 piece=▁예민
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=1480 all=32044 active=1949 piece=▁사람에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=1500 all=32106 active=2011 piece=받고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=1520 all=32236 active=1725 piece=▁번호
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=1540 all=32304 active=1793 piece=▁마음은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=1560 all=32355 active=1844 piece=▁멍
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=1580 all=32485 active=1974 piece=자는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=1600 all=32565 active=2054 piece=▁흔들
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=1620 all=32593 active=1651 piece=▁기다리고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=1640 all=32672 active=1730 piece=▁고마
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=1660 all=32744 active=1802 piece=▁잠수
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=1680 all=32804 active=1862 piece=▁제대로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=1700 all=32853 active=1911 piece=내서
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=1720 all=32963 active=1750 piece=▁버려
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=1740 all=33042 active=1829 piece=▁하기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=1760 all=33063 active=1850 piece=▁되겠네요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=1780 all=33144 active=1931 piece=워질
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=1800 all=33236 active=2023 piece=▁새벽
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=1820 all=33308 active=1731 piece=▁그리워
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=1840 all=33321 active=1744 piece=▁말씀해주세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=1860 all=33451 active=1874 piece=음을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=1880 all=33519 active=1942 piece=▁바뀌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=1900 all=33592 active=2015 piece=▁퇴근
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=1920 all=33625 active=1709 piece=▁다이어트
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=1940 all=33644 active=1728 piece=▁억
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=1960 all=33756 active=1840 piece=▁견디
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=1980 all=33806 active=1890 piece=▁오해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=2000 all=33876 active=1960 piece=▁뭐하지
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=2020 all=33878 active=1696 piece=▁호감을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=2040 all=33887 active=1705 piece=▁썼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=2060 all=34037 active=1855 piece=할지
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=2080 all=34103 active=1921 piece=▁비슷
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=2100 all=34141 active=1959 piece=으려고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=2120 all=34164 active=1722 piece=▁연애는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=2140 all=34154 active=1712 piece=▁여자친구의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2160 all=34190 active=1748 piece=남자
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2180 all=34332 active=1890 piece=▁공허
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2200 all=34372 active=1930 piece=▁부럽
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2220 all=34437 active=1781 piece=▁외로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2240 all=34495 active=1839 piece=한다면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2260 all=34523 active=1867 piece=▁썸타는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2280 all=34535 active=1879 piece=▁할텐데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=2300 all=34533 active=1877 piece=▁필요하죠
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2320 all=34560 active=1754 piece=냐에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2340 all=34646 active=1840 piece=▁나왔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2360 all=34682 active=1876 piece=▁수록
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2380 all=34719 active=1913 piece=▁취향
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2400 all=34762 active=1956 piece=▁됩니다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2420 all=34762 active=1739 piece=▁언제쯤
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2440 all=34754 active=1731 piece=▁말이에요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=2460 all=34741 active=1718 piece=▁부담스럽지
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2480 all=34758 active=1735 piece=▁잃
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2500 all=34850 active=1827 piece=아지
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2520 all=34913 active=1801 piece=▁곳에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2540 all=34929 active=1817 piece=▁무리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2560 all=34969 active=1857 piece=▁올라
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2580 all=35031 active=1919 piece=▁하네
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2600 all=35084 active=1972 piece=▁느낌이
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2620 all=35087 active=1758 piece=▁여���를
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2640 all=35095 active=1766 piece=▁무엇이든
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=2660 all=35083 active=1754 piece=▁습관이에요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2680 all=35109 active=1780 piece=▁핑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2700 all=35190 active=1861 piece=우면
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2720 all=35257 active=1820 piece=▁달콤
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2740 all=35290 active=1853 piece=▁보니
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2760 all=35330 active=1893 piece=▁용서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2780 all=35364 active=1927 piece=▁휴가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2800 all=35419 active=1982 piece=▁노래방
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2820 all=35418 active=1769 piece=▁시기가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2840 all=35405 active=1756 piece=▁찾아가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2860 all=35418 active=1769 piece=▁생각하면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=2880 all=35408 active=1759 piece=▁다녀오세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=2900 all=35422 active=1773 piece=▁녹
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=2920 all=35498 active=1843 piece=따라
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=2940 all=35602 active=1947 piece=혼자
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=2960 all=35623 active=1968 piece=▁늦은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=2980 all=35656 active=2001 piece=▁봄이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3000 all=35670 active=2015 piece=▁여름
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3020 all=35704 active=1815 piece=▁회식
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3040 all=35772 active=1883 piece=▁결혼은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3060 all=35771 active=1882 piece=▁못해요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3080 all=35763 active=1874 piece=▁왔으면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3100 all=35759 active=1870 piece=▁좋으면
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3120 all=35745 active=1774 piece=▁두근거리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3140 all=35740 active=1769 piece=▁지났네요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=3160 all=35731 active=1760 piece=▁마련이에요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3180 all=35728 active=1757 piece=▁봉
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3200 all=35771 active=1800 piece=럽게
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3220 all=35858 active=1873 piece=테리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3240 all=35899 active=1914 piece=▁너도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3260 all=35930 active=1945 piece=▁뭐라
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3280 all=35961 active=1976 piece=▁순수
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3300 all=35992 active=2007 piece=▁웬수
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3320 all=36017 active=1822 piece=▁착한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3340 all=36059 active=1864 piece=▁후가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3360 all=36129 active=1934 piece=해야할
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3380 all=36136 active=1941 piece=▁누구든
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3400 all=36129 active=1934 piece=▁뭐할까
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3420 all=36121 active=1799 piece=▁아이돌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3440 all=36121 active=1799 piece=▁전화가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3460 all=36128 active=1806 piece=▁기다리면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3480 all=36109 active=1787 piece=▁우선순위
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=3500 all=36113 active=1791 piece=▁물어보는게
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3520 all=36093 active=1786 piece=▁검
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3540 all=36124 active=1817 piece=▁탔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3560 all=36182 active=1875 piece=려서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3580 all=36258 active=1951 piece=장에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3600 all=36287 active=1980 piece=▁겨우
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3620 all=36293 active=1821 piece=▁놀죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3640 all=36320 active=1848 piece=▁버티
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3660 all=36345 active=1873 piece=▁약을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3680 all=36354 active=1882 piece=▁조건
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3700 all=36380 active=1908 piece=▁풀어
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3720 all=36437 active=1871 piece=적이야
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3740 all=36458 active=1892 piece=▁기숙사
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3760 all=36443 active=1877 piece=▁만드는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3780 all=36439 active=1873 piece=▁보여요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3800 all=36428 active=1862 piece=▁아름답
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3820 all=36431 active=1822 piece=▁일부터
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3840 all=36427 active=1818 piece=▁하고싶
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3860 all=36426 active=1817 piece=▁기다리지
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3880 all=36413 active=1804 piece=▁생각할까
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3900 all=36396 active=1787 piece=▁첫사랑이
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3920 all=36393 active=1813 piece=▁다음부터는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3940 all=36377 active=1797 piece=▁축하합니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3960 all=36386 active=1806 piece=▁밖
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3980 all=36429 active=1849 piece=교통
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4000 all=36489 active=1909 piece=면증
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4020 all=36553 active=1886 piece=절한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4040 all=36599 active=1932 piece=형이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4060 all=36622 active=1955 piece=▁금연
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4080 all=36646 active=1979 piece=▁도망
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4100 all=36654 active=1987 piece=▁뭐하
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4120 all=36671 active=1848 piece=▁소유
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4140 all=36679 active=1856 piece=▁아깝
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4160 all=36701 active=1878 piece=▁요구
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4180 all=36713 active=1890 piece=▁잡는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4200 all=36734 active=1911 piece=▁참아
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4220 all=36767 active=1866 piece=▁표시
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4240 all=36783 active=1882 piece=되는데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4260 all=36843 active=1942 piece=하다면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4280 all=36861 active=1960 piece=▁경우가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4300 all=36848 active=1947 piece=▁너무나
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4320 all=36836 active=1830 piece=▁뜻대로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4340 all=36826 active=1820 piece=▁방법을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4360 all=36812 active=1806 piece=▁술먹고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4380 all=36799 active=1793 piece=▁어젯밤
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4400 all=36788 active=1782 piece=▁자괴감
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4420 all=36785 active=1835 piece=▁짜장면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4440 all=36779 active=1829 piece=▁하루가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4460 all=36786 active=1836 piece=▁고민하게
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4480 all=36770 active=1820 piece=▁돌아가고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4500 all=36757 active=1807 piece=▁소개시켜
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4520 all=36751 active=1829 piece=▁이야기해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4540 all=36737 active=1815 piece=▁하나라도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4560 all=36725 active=1803 piece=▁빌려보세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4580 all=36707 active=1785 piece=▁정류장에서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4600 all=36690 active=1768 piece=▁이용해주세요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4620 all=36692 active=1837 piece=▁밟
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4640 all=36724 active=1869 piece=▁퍼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4660 all=36771 active=1916 piece=드시
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4680 all=36818 active=1963 piece=수를
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4700 all=36883 active=2028 piece=의금
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4720 all=36929 active=1889 piece=▁20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4740 all=36931 active=1891 piece=▁괜한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4760 all=36950 active=1910 piece=▁내게
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4780 all=36948 active=1908 piece=▁등산
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4800 all=36956 active=1916 piece=▁무의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4820 all=36966 active=1856 piece=▁봄은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4840 all=36978 active=1868 piece=▁수업
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4860 all=36987 active=1877 piece=▁어깨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4880 all=37008 active=1898 piece=▁잔인
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4900 all=37017 active=1907 piece=▁착잡
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4920 all=37037 active=1868 piece=▁한계
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4940 all=37073 active=1904 piece=릅니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4960 all=37119 active=1950 piece=했네요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4980 all=37116 active=1947 piece=▁기다림
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5000 all=37109 active=1940 piece=▁되는거
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5020 all=37101 active=1847 piece=▁말했어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5040 all=37095 active=1841 piece=▁믿음을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5060 all=37086 active=1832 piece=▁빌어요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5080 all=37075 active=1821 piece=▁신경써
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5100 all=37070 active=1816 piece=▁연락할
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5120 all=37060 active=1844 piece=▁재회는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5140 all=37048 active=1832 piece=▁친구는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5160 all=37037 active=1821 piece=▁함께할
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5180 all=37050 active=1834 piece=▁가능하면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5200 all=37036 active=1820 piece=▁들어왔어
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5220 all=37021 active=1837 piece=▁사랑해요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5240 all=37009 active=1825 piece=▁아는데도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5260 all=36999 active=1815 piece=▁인생이죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5280 all=36983 active=1799 piece=▁주변에서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5300 all=36969 active=1785 piece=담해보세요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5320 all=36957 active=1835 piece=▁붙여보세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5340 all=36939 active=1817 piece=▁좋아한다는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5360 all=36925 active=1803 piece=▁객
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5380 all=36950 active=1828 piece=▁뻑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5400 all=36963 active=1841 piece=가가
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5420 all=37006 active=1890 piece=꼬박
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5440 all=37040 active=1924 piece=름이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5460 all=37068 active=1952 piece=뻑해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5480 all=37102 active=1986 piece=오래
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5500 all=37144 active=2028 piece=지우
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5520 all=37181 active=1889 piece=한건
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5540 all=37202 active=1910 piece=▁걔는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5560 all=37202 active=1910 piece=▁꾹꾹
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5580 all=37200 active=1908 piece=▁누락
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5600 all=37202 active=1910 piece=▁땀을
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5620 all=37196 active=1855 piece=▁멈춰
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5640 all=37207 active=1866 piece=▁바꿨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5660 all=37224 active=1883 piece=▁불효
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5680 all=37241 active=1900 piece=▁손편
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5700 all=37258 active=1917 piece=▁안할
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5720 all=37266 active=1869 piece=▁오셨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5740 all=37265 active=1868 piece=▁이끌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5760 all=37283 active=1886 piece=▁전과
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5780 all=37296 active=1899 piece=▁지루
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5800 all=37311 active=1914 piece=▁축제
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5820 all=37313 active=1867 piece=▁패션
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5840 all=37321 active=1875 piece=▁확률
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5860 all=37346 active=1900 piece=사람은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5880 all=37388 active=1942 piece=해졌죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5900 all=37400 active=1954 piece=▁갈수록
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5920 all=37383 active=1853 piece=▁괜찮길
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5940 all=37370 active=1840 piece=▁끊겼어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5960 all=37357 active=1827 piece=▁답답할
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5980 all=37344 active=1814 piece=▁들이대
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6000 all=37334 active=1804 piece=▁말아야
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6020 all=37326 active=1857 piece=▁몸에는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6040 all=37310 active=1841 piece=▁보기로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6060 all=37298 active=1829 piece=▁사귀어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6080 all=37286 active=1817 piece=▁속이는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6100 all=37277 active=1808 piece=▁아니길
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6120 all=37269 active=1856 piece=▁애프터
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6140 all=37257 active=1844 piece=▁영양제
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6160 all=37242 active=1829 piece=▁위험해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6180 all=37236 active=1823 piece=▁입냄새
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6200 all=37229 active=1816 piece=▁전여자
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6220 all=37217 active=1848 piece=▁줄어들
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6240 all=37204 active=1835 piece=▁커플링
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6260 all=37187 active=1818 piece=▁할까요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6280 all=37179 active=1810 piece=받으세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6300 all=37199 active=1830 piece=▁감으세요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6320 all=37190 active=1851 piece=▁그렇겠죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6340 all=37174 active=1835 piece=▁놀이공원
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6360 all=37155 active=1816 piece=▁마음에서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6380 all=37137 active=1798 piece=▁벗어나는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6400 all=37125 active=1786 piece=▁사생활이
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6420 all=37108 active=1840 piece=▁신경쓰고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6440 all=37093 active=1825 piece=▁어머어머
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6460 all=37075 active=1807 piece=▁원한다면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6480 all=37063 active=1795 piece=▁있는걸까
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6500 all=37046 active=1778 piece=▁차였는데
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6520 all=37031 active=1838 piece=▁하다보니
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6540 all=37012 active=1819 piece=▁힘들지만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6560 all=37006 active=1813 piece=▁나갈거예요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6580 all=36986 active=1793 piece=▁로봇이에요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6600 all=36967 active=1774 piece=▁선택이었을
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6620 all=36948 active=1829 piece=▁연락이라도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6640 all=36929 active=1810 piece=▁정신건강에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6660 all=36912 active=1793 piece=▁하우스웨딩
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6680 all=36894 active=1775 piece=▁운동해보세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6700 all=36874 active=1755 piece=▁?
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6720 all=36882 active=1852 piece=▁뒀
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6740 all=36900 active=1870 piece=▁잼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6760 all=36910 active=1880 piece=▁홧
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6780 all=36934 active=1904 piece=근해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6800 all=36958 active=1928 piece=는다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6820 all=36983 active=1871 piece=때문
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6840 all=37015 active=1903 piece=받은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6860 all=37054 active=1942 piece=서요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6880 all=37081 active=1969 piece=싸움
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6900 all=37116 active=2004 piece=와도
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6920 all=37142 active=1880 piece=저히
# trainer_interface.cc(689) LOG(INFO) Saving model: /home/jovyan/work/transformer_chatbot/data/spm_chatbot.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: /home/jovyan/work/transformer_chatbot/data/spm_chatbot.vocab

# %%
# ===== 4. GPT-1 방식 데이터셋 클래스 =====
class GPTChatbotDataset(Dataset):
    """
    변경사항: GPT-1 방식으로 데이터셋 구성
    - Q와 A를 하나의 시퀀스로 연결
    - 언어 모델링 목적함수 사용 (다음 토큰 예측)
    """
    def __init__(self, dataframe, tokenizer, max_length=128):
        self.data = dataframe.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_length = max_length
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        question = row['Q']
        answer = row['A']
        
        # 변경사항: Q + <SEP> + A 형태로 하나의 시퀀스 구성
        combined_text = question + " <SEP> " + answer
        
        # 토큰화: BOS + 텍스트 + EOS
        tokens = [BOS_ID] + self.tokenizer.encode_as_ids(combined_text) + [EOS_ID]
        
        # 패딩 또는 자르기
        if len(tokens) > self.max_length:
            tokens = tokens[:self.max_length]
        else:
            tokens = tokens + [PAD_ID] * (self.max_length - len(tokens))
        
        # 언어 모델링: input과 target이 한 칸씩 shift
        input_ids = tokens[:-1]  # 마지막 토큰 제외
        target_ids = tokens[1:]  # 첫 번째 토큰 제외
        
        return {
            'input_ids': torch.tensor(input_ids, dtype=torch.long),
            'target_ids': torch.tensor(target_ids, dtype=torch.long)
        }

# %%
# ===== 5. GPT-1 트랜스포머 모델 구현 =====

class LearnedPositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length=512):
        super().__init__()
        self.position_embeddings = nn.Embedding(max_seq_length, d_model)
        
    def forward(self, x):
        batch_size, seq_len = x.size()[:2]
        position_ids = torch.arange(seq_len, device=x.device).expand(batch_size, seq_len)
        return self.position_embeddings(position_ids)

class GELU(nn.Module):
    def forward(self, x):
        return 0.5 * x * (1.0 + torch.tanh(math.sqrt(2.0 / math.pi) * (x + 0.044715 * torch.pow(x, 3.0))))

class CausalMultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads, dropout=0.1):
        super().__init__()
        assert d_model % num_heads == 0
        
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        
        self.qkv_proj = nn.Linear(d_model, 3 * d_model, bias=True)
        self.out_proj = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, mask=None):
        batch_size, seq_len = x.size()[:2]
        
        # Q, K, V 계산
        qkv = self.qkv_proj(x)
        q, k, v = qkv.chunk(3, dim=-1)
        
        # Multi-head로 reshape
        q = q.view(batch_size, seq_len, self.num_heads, self.d_k).transpose(1, 2)
        k = k.view(batch_size, seq_len, self.num_heads, self.d_k).transpose(1, 2)
        v = v.view(batch_size, seq_len, self.num_heads, self.d_k).transpose(1, 2)
        
        # Scaled dot-product attention
        attn_scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(self.d_k)
        
        # 마스크 적용 - 수정된 부분
        if mask is not None:
            attn_scores = attn_scores.masked_fill(mask == 0, -1e9)
        
        attn_probs = F.softmax(attn_scores, dim=-1)
        attn_probs = self.dropout(attn_probs)
        
        # Attention 적용
        attn_output = torch.matmul(attn_probs, v)
        attn_output = attn_output.transpose(1, 2).contiguous().view(batch_size, seq_len, self.d_model)
        
        return self.out_proj(attn_output)

class GPTFeedForward(nn.Module):
    def __init__(self, d_model, d_ff, dropout=0.1):
        super().__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.gelu = GELU()
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.gelu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

class GPTDecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.self_attn = CausalMultiHeadAttention(d_model, num_heads, dropout)
        
        self.ln2 = nn.LayerNorm(d_model) 
        self.feed_forward = GPTFeedForward(d_model, d_ff, dropout)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, mask=None):
        # Pre-LayerNorm 구조
        x = x + self.dropout(self.self_attn(self.ln1(x), mask))
        x = x + self.dropout(self.feed_forward(self.ln2(x)))
        
        return x

class GPTChatbot(nn.Module):
    def __init__(self, vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super().__init__()
        self.d_model = d_model
        self.max_seq_length = max_seq_length
        
        # 임베딩 레이어들
        self.token_embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoding = LearnedPositionalEncoding(d_model, max_seq_length)
        
        # 디코더 레이어들
        self.decoder_layers = nn.ModuleList([
            GPTDecoderLayer(d_model, num_heads, d_ff, dropout) 
            for _ in range(num_layers)
        ])
        
        # 최종 LayerNorm
        self.ln_final = nn.LayerNorm(d_model)
        
        # Language modeling head
        self.lm_head = nn.Linear(d_model, vocab_size, bias=False)
        
        self.dropout = nn.Dropout(dropout)
        
        # 가중치 초기화
        self.apply(self._init_weights)
        
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)
    
    def generate_causal_mask(self, seq_len, device):
        
        mask = torch.tril(torch.ones(seq_len, seq_len, device=device, dtype=torch.bool))
        return mask.unsqueeze(0).unsqueeze(0)  # (1, 1, seq_len, seq_len)
    
    def forward(self, input_ids):
        batch_size, seq_len = input_ids.size()
        
        # 패딩 마스크 생성 
        pad_mask = (input_ids != PAD_ID).unsqueeze(1).unsqueeze(2)  # boolean
        
        # Causal mask 생성 
        causal_mask = self.generate_causal_mask(seq_len, input_ids.device)  # boolean
        
        # 두 마스크를 결합 
        combined_mask = pad_mask & causal_mask
        
        # 임베딩: 토큰 + 포지션
        token_embeds = self.token_embedding(input_ids) * math.sqrt(self.d_model)
        pos_embeds = self.pos_encoding(input_ids)
        
        x = self.dropout(token_embeds + pos_embeds)
        
        # 디코더 레이어들 통과
        for layer in self.decoder_layers:
            x = layer(x, combined_mask)
        
        # 최종 LayerNorm
        x = self.ln_final(x)
        
        # Language modeling head
        logits = self.lm_head(x)
        
        return logits

# %%
# ===== 6. 데이터 로더 준비 =====
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)

train_dataset = GPTChatbotDataset(train_df, sp, max_length=128)  # GPT 데이터셋 사용
val_dataset = GPTChatbotDataset(val_df, sp, max_length=128)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

print(f"학습 데이터: {len(train_dataset)}개")
print(f"검증 데이터: {len(val_dataset)}개")
# Out:
# 학습 데이터: 10575개
# 검증 데이터: 1175개

# %%
# ===== 7. 모델 설정 ====
model = GPTChatbot(
    vocab_size=vocab_size,
    d_model=128,        
    num_heads=4,        
    num_layers=4,       
    d_ff=512,          
    max_seq_length=128,
    dropout=0.3       
)

criterion = nn.CrossEntropyLoss(ignore_index=PAD_ID)
optimizer = optim.Adam(model.parameters(), lr=0.005)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(f"Using device: {device}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Using device: cuda
# Model parameters: 2,857,728

# %%
# ===== 8. 학습 함수 (GPT-1 방식으로 수정) =====
def train_epoch(model, train_loader, criterion, optimizer, device):
    """
    변경사항: 언어 모델링 목적함수로 학습
    """
    model.train()
    total_loss = 0
    
    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        target_ids = batch['target_ids'].to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        logits = model(input_ids)
        
        # Loss 계산 (다음 토큰 예측)
        loss = criterion(logits.view(-1, vocab_size), target_ids.view(-1))
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    return total_loss / len(train_loader)

def validate_epoch(model, val_loader, criterion, device):
    """
    변경사항: 언어 모델링 목적함수로 검증
    """
    model.eval()
    total_loss = 0
    
    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['input_ids'].to(device)
            target_ids = batch['target_ids'].to(device)
            
            logits = model(input_ids)
            loss = criterion(logits.view(-1, vocab_size), target_ids.view(-1))
            
            total_loss += loss.item()
    
    return total_loss / len(val_loader)

# %%
# ===== 9. 학습 실행 =====
best_val_loss = float('inf')
patience = 5
patience_counter = 0

num_epochs = 30
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    train_loss = train_epoch(model, train_loader, criterion, optimizer, device)
    val_loss = validate_epoch(model, val_loader, criterion, device)
    
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    
    # Early Stopping 체크
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_gpt_chatbot.pth')
       
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping!")
            break

print("학습 완료!")
# Out:
# Epoch 1/30: Train Loss: 5.7529, Val Loss: 5.3375
# Epoch 2/30: Train Loss: 5.1055, Val Loss: 5.0284
# Epoch 3/30: Train Loss: 4.8061, Val Loss: 4.8858
# Epoch 4/30: Train Loss: 4.6004, Val Loss: 4.7626
# Epoch 5/30: Train Loss: 4.4279, Val Loss: 4.7143
# Epoch 6/30: Train Loss: 4.2805, Val Loss: 4.6507
# Epoch 7/30: Train Loss: 4.1677, Val Loss: 4.6495
# Epoch 8/30: Train Loss: 4.1145, Val Loss: 4.6396
# Epoch 9/30: Train Loss: 4.0122, Val Loss: 4.6289
# Epoch 10/30: Train Loss: 3.9340, Val Loss: 4.6309
# Epoch 11/30: Train Loss: 3.8730, Val Loss: 4.6082
# Epoch 12/30: Train Loss: 3.8253, Val Loss: 4.6046
# Epoch 13/30: Train Loss: 3.7627, Val Loss: 4.5988
# Epoch 14/30: Train Loss: 3.7216, Val Loss: 4.6037
# Epoch 15/30: Train Loss: 3.6667, Val Loss: 4.6355
# Epoch 16/30: Train Loss: 3.6467, Val Loss: 4.6197
# Epoch 17/30: Train Loss: 3.6214, Val Loss: 4.5680
# Epoch 18/30: Train Loss: 3.5846, Val Loss: 4.6161
# Epoch 19/30: Train Loss: 3.5657, Val Loss: 4.6193
# Epoch 20/30: Train Loss: 3.5345, Val Loss: 4.6394
# Epoch 21/30: Train Loss: 3.5321, Val Loss: 4.6076
# Epoch 22/30: Train Loss: 3.5187, Val Loss: 4.6249
# Early stopping!
# 학습 완료!

# %%
# ===== 10. GPT-1 방식 추론 함수 =====
def generate_response(model, question, max_length=64, temperature=0.8, top_k=50):
    model.eval()
    
    with torch.no_grad():
        # 입력 준비: Question + <SEP>
        input_text = question + " <SEP>"
        input_ids = [BOS_ID] + sp.encode_as_ids(input_text)
        input_tensor = torch.tensor([input_ids], dtype=torch.long).to(device)
        
        # 자동회귀 생성
        for _ in range(max_length):
            # 현재 시퀀스에서 다음 토큰 예측
            logits = model(input_tensor)
            next_token_logits = logits[0, -1, :] / temperature
            
            # Top-k 샘플링
            if top_k > 0:
                values, indices = torch.topk(next_token_logits, top_k)
                next_token_logits[next_token_logits < values[-1]] = -float('inf')
            
            # 다음 토큰 샘플링
            probs = F.softmax(next_token_logits, dim=-1)
            next_token = torch.multinomial(probs, 1)
            
            # EOS 토큰이면 종료
            if next_token.item() == EOS_ID:
                break
            
            # 시퀀스에 추가
            input_tensor = torch.cat([input_tensor, next_token.unsqueeze(0)], dim=1)
        
        # 응답 부분만 추출
        generated_ids = input_tensor[0].tolist()
        
        # <SEP> 이후 부분만 디코딩
        sep_idx = None
        for i, token_id in enumerate(generated_ids):
            if token_id == SEP_ID:
                sep_idx = i
                break
        
        if sep_idx is not None and sep_idx + 1 < len(generated_ids):
            response_ids = generated_ids[sep_idx + 1:]
            # BOS, EOS, PAD 제거
            response_ids = [id for id in response_ids if id not in [BOS_ID, EOS_ID, PAD_ID]]
            response = sp.decode_ids(response_ids).strip()
        else:
            response = "죄송합니다. 답변을 생성할 수 없습니다."
    
    return response

# %%
# ===== 11. 테스트 =====
# 모델 로드
model.load_state_dict(torch.load('best_gpt_chatbot.pth'))

test_questions = [
    "안녕하세요", 
    "오늘 날씨 어때?", 
    "뭐하고 있어?",
    "고마워",
    "미안해",
    "사랑이란 무엇일까?"
]

print("=== GPT-1 챗봇 테스트 ===")
for q in test_questions:
    response = generate_response(model, q, max_length=32, temperature=0.8)
    print(f"Q: {q}")
    print(f"A: {response}\n")
# Out:
# === GPT-1 챗봇 테스트 ===
# Q: 안녕하세요
# A: 회원정보 찾기를 해보세요.
#
# Q: 오늘 날씨 어때?
# A: 저도 해보고 싶네요.
#
# Q: 뭐하고 있어?
# A: 어떤 말도 위로가 되지 않으니까요.
#
# Q: 고마워
# A: 저도 좀 더 힘들거예요.
#
# Q: 미안해
# A: 저도 받아들여야 할 거예요.
#
# Q: 사랑이란 무엇일까?
# A: 당신이 옆에 있어요.
